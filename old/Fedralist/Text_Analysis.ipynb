# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001


def calc_term_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    prob = 1
    return prob


# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    """
    Gets probability of a word:
    Returns probability if word exists, EPSILON if not
    """
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    """
    Calculates word probabilities:
    1. Counts word frequencies
    2. Converts counts to probabilities
    Returns: word probability dictionary
    """
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    """
    Reads a file and counts word frequencies:
    1. Opens file
    2. Splits into words
    3. Standardizes each word
    4. Counts occurrences
    Returns: (wordMap, total word count)
    """
    wordMap = {}
    nWords = 0
    with open(fileName ,encoding="utf-8") as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    """
    Updates word count in dictionary:
    1. Skips stop words
    2. Initializes count if new word
    3. Increments count if existing word
    """
    if is_stop(word):
        return
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1


def standardize(word):
    """
    Standardizes words by:
    1. Converting to lowercase
    2. Removing punctuation
    3. Keeping only alphabetic characters
    """
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

def is_stop(word):
    """
    Removes common words that don't help in analysis
    """
    stop_words = ['to', 'i', 'the', 'and', 'of']
    return word in stop_words


def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    print("hamilton['congress']\t", hamilton_word_prob['congress'])
    print("madison['congress']\t",  madison_word_prob['congress'])
    print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_term_doc_given_author(hamilton_word_prob, unknown_doc_count)
    print('---'*10)
    madison_term = calc_term_doc_given_author(madison_word_prob, unknown_doc_count)
    print("Hamilton Term\t", hamilton_term)
    print("Madison Term\t",madison_term)

if __name__ == '__main__':
    main()
# Out:
# hamilton['congress']	 0.0011592117360195067
# madison['congress']	 0.00016016229779509903
# doc_count['congress']	 1
# n_words 2172
# ------------------------------
# Hamilton Term	 1
# Madison Term	 1

# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001



def calc_term_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    prob = 1
    for word, c_i in counts.items():
        p_word = get_word_prob(prob_map, word)
        prob *= p_word ** c_i
        print("word: ", word,"| prob_word: ", p_word, "| c_i: ", c_i, "| prob: ", prob)
    return prob
    # prob = 0
    # for word, c_i in counts.items():
    #     p_word = get_word_prob(prob_map, word)
    #     prob += math.log(p_word) * c_i
    # return prob


# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    with open(fileName ,encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if is_stop(word):
        return
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1

# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

def is_stop(word):
    stop_words = ['to', 'i', 'the', 'and', 'of']
    return word in stop_words

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    print("hamilton['congress']\t", hamilton_word_prob['congress'])
    print("madison['congress']\t",  madison_word_prob['congress'])
    print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_term_doc_given_author(hamilton_word_prob, unknown_doc_count)
    print('---'*10)
    madison_term = calc_term_doc_given_author(madison_word_prob, unknown_doc_count)
    print("Hamilton Term\t", hamilton_term)
    print("Madison Term\t",madison_term)

if __name__ == '__main__':
    main()
# Out:
# hamilton['congress']	 0.0011592117360195067
# madison['congress']	 0.00016016229779509903
# doc_count['congress']	 1
# n_words 2172
# word:  people prob_word:  0.0021585321981052886 c_i:  7 prob:  2.183281419899546e-19
# word:  state prob_word:  0.0024383419274893073 c_i:  8 prob:  2.7281394801783755e-40
ob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  for prob_word:  0.008234400607586841 c_i:  21 prob:  0.0
# word:  proof prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  beyond prob_word:  0.0002398369109005876 c_i:  2 prob:  0.0
# word:  case prob_word:  0.0006395650957349003 c_i:  4 prob:  0.0
# word:  before prob_word:  0.0004796738218011752 c_i:  2 prob:  0.0
# word:  us prob_word:  0.0021185593796218573 c_i:  2 prob:  0.0
# word:  what prob_word:  0.0009593476436023504 c_i:  4 prob:  0.0
# word:  on prob_word:  0.003757444937442539 c_i:  8 prob:  0.0
# word:  this prob_word:  0.0069552704161170405 c_i:  15 prob:  0.0
# word:  no prob_word:  0.0022384778350721508 c_i:  10 prob:  0.0
# word:  man prob_word:  0.0006795379142183315 c_i:  2 prob:  0.0
# word:  will prob_word:  0.008394291881520567 c_i:  25 prob:  0.0
# word:  subject prob_word:  0.000599592277251469 c_i:  5 prob:  0.0
# word:  himself prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  ridicule prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  pretending prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  any prob_word:  0.0019986409241715634 c_i:  6 prob:  0.0
# word:  natural prob_word:  0.0006795379142183315 c_i:  2 prob:  0.0
# word:  connection prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  subsists prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  between prob_word:  0.0009193748251189191 c_i:  7 prob:  0.0
# word:  sun prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  or prob_word:  0.005955949954031259 c_i:  12 prob:  0.0
# word:  seasons prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  period prob_word:  0.00031978254786745015 c_i:  7 prob:  0.0
# word:  within prob_word:  0.0005196466402846065 c_i:  4 prob:  0.0
# word:  human prob_word:  0.00039972818483431264 c_i:  1 prob:  0.0
# word:  virtue prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  can prob_word:  0.002278450653555582 c_i:  13 prob:  0.0
# word:  bear prob_word:  0.00015989127393372507 c_i:  3 prob:  0.0
# word:  temptations prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  power prob_word:  0.0021585321981052886 c_i:  4 prob:  0.0
# word:  happily prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  mankind prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  liberty prob_word:  0.0010792660990526443 c_i:  5 prob:  0.0
# word:  respect prob_word:  0.0008394291881520566 c_i:  1 prob:  0.0
# word:  confined prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  single prob_word:  0.0004796738218011752 c_i:  5 prob:  0.0
# word:  point prob_word:  0.00015989127393372507 c_i:  2 prob:  0.0
# word:  time prob_word:  0.001958668105688132 c_i:  5 prob:  0.0
# word:  but prob_word:  0.004077227485309989 c_i:  11 prob:  0.0
# word:  lies prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  extremes prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  afford prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  sufficient prob_word:  0.00031978254786745015 c_i:  2 prob:  0.0
# word:  latitude prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  all prob_word:  0.0036774993004756763 c_i:  9 prob:  0.0
# word:  variations prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  may prob_word:  0.004117200303793421 c_i:  7 prob:  0.0
# word:  required prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  by prob_word:  0.007514889874885078 c_i:  31 prob:  0.0
# word:  various prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  situations prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  circumstances prob_word:  0.0006395650957349003 c_i:  4 prob:  0.0
# word:  civil prob_word:  0.0007994563696686253 c_i:  3 prob:  0.0
# word:  society prob_word:  0.00031978254786745015 c_i:  1 prob:  0.0
# word:  election prob_word:  7.994563696686254e-05 c_i:  4 prob:  0.0
# word:  magistrates prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  might prob_word:  0.0012391573729863693 c_i:  3 prob:  0.0
# word:  were prob_word:  0.001199184554502938 c_i:  4 prob:  0.0
# word:  found prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  expedient prob_word:  0.0002398369109005876 c_i:  2 prob:  0.0
# word:  some prob_word:  0.0009993204620857817 c_i:  12 prob:  0.0
# word:  instances prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  actually prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  daily prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  weekly prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  monthly prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  well prob_word:  0.0009993204620857817 c_i:  4 prob:  0.0
# word:  require prob_word:  0.00031978254786745015 c_i:  2 prob:  0.0
# word:  deviation prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  from prob_word:  0.005196466402846065 c_i:  11 prob:  0.0
# word:  rule prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  one prob_word:  0.0021585321981052886 c_i:  7 prob:  0.0
# word:  side prob_word:  0.00039972818483431264 c_i:  2 prob:  0.0
# word:  why prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  also prob_word:  0.0003597553663508814 c_i:  4 prob:  0.0
# word:  other prob_word:  0.002878042930807051 c_i:  14 prob:  0.0
# word:  turning prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  our prob_word:  0.00443698285166087 c_i:  4 prob:  0.0
# word:  attention prob_word:  0.00039972818483431264 c_i:  5 prob:  0.0
# word:  periods prob_word:  7.994563696686254e-05 c_i:  3 prob:  0.0
# word:  among prob_word:  0.0008794020066354879 c_i:  3 prob:  0.0
# word:  ourselves prob_word:  0.00039972818483431264 c_i:  1 prob:  0.0
# word:  most prob_word:  0.0017588040132709758 c_i:  8 prob:  0.0
# word:  numerous prob_word:  0.00031978254786745015 c_i:  2 prob:  0.0
# word:  branches prob_word:  7.994563696686254e-05 c_i:  3 prob:  0.0
# word:  legislatures prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  we prob_word:  0.003917336211376264 c_i:  4 prob:  0.0
# word:  find prob_word:  0.00031978254786745015 c_i:  1 prob:  0.0
# word:  means prob_word:  0.0007994563696686253 c_i:  5 prob:  0.0
# word:  coinciding prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  more prob_word:  0.0033577167526082263 c_i:  10 prob:  0.0
# word:  instance prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  than prob_word:  0.0027581244753567572 c_i:  7 prob:  0.0
# word:  connecticut prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  rhode prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  island prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  halfyearly prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  states prob_word:  0.0029180157492904825 c_i:  16 prob:  0.0
# word:  south prob_word:  1e-06 c_i:  3 prob:  0.0
# word:  carolina prob_word:  1e-06 c_i:  3 prob:  0.0
# word:  excepted prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  biennial prob_word:  1e-06 c_i:  4 prob:  0.0
# word:  proposed prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  federal prob_word:  0.0008394291881520566 c_i:  9 prob:  0.0
# word:  government prob_word:  0.0027980972938401885 c_i:  15 prob:  0.0
# word:  difference prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  four prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  longest prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  shortest prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  yet prob_word:  0.0006395650957349003 c_i:  3 prob:  0.0
# word:  would prob_word:  0.005796058680097534 c_i:  6 prob:  0.0
# word:  easy prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  show prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  better prob_word:  0.00039972818483431264 c_i:  2 prob:  0.0
# word:  governed prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  enjoys prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  greater prob_word:  0.0005596194587680377 c_i:  3 prob:  0.0
# word:  share prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  rational prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  either prob_word:  0.0009993204620857817 c_i:  2 prob:  0.0
# word:  these prob_word:  0.00219850501658872 c_i:  10 prob:  0.0
# word:  distinguished prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  respects prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  causes prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  whose prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  different prob_word:  0.0007195107327017628 c_i:  7 prob:  0.0
# word:  both prob_word:  0.0003597553663508814 c_i:  3 prob:  0.0
# word:  searching prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  grounds prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  doctrine prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  discover prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  wholly prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  inapplicable prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  important prob_word:  0.00039972818483431264 c_i:  1 prob:  0.0
# word:  distinction prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  so prob_word:  0.001798776831754407 c_i:  4 prob:  0.0
# word:  understood prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  america prob_word:  0.000599592277251469 c_i:  2 prob:  0.0
# word:  constitution prob_word:  0.000599592277251469 c_i:  6 prob:  0.0
# word:  unalterable prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  law prob_word:  0.00039972818483431264 c_i:  2 prob:  0.0
# word:  alterable prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  seems prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  have prob_word:  0.007155134508534197 c_i:  7 prob:  0.0
# word:  little prob_word:  0.0008794020066354879 c_i:  3 prob:  0.0
# word:  observed prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  country prob_word:  0.0011192389175360754 c_i:  1 prob:  0.0
# word:  wherever prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  supreme prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  legislation prob_word:  1e-06 c_i:  7 prob:  0.0
# word:  resided prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  supposed prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  reside prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  full prob_word:  0.00043970100331774394 c_i:  1 prob:  0.0
# word:  change prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  form prob_word:  0.0003597553663508814 c_i:  3 prob:  0.0
# word:  even prob_word:  0.000599592277251469 c_i:  4 prob:  0.0
# word:  great prob_word:  0.001958668105688132 c_i:  3 prob:  0.0
# word:  britain prob_word:  0.00039972818483431264 c_i:  1 prob:  0.0
# word:  principles prob_word:  0.00043970100331774394 c_i:  1 prob:  0.0
# word:  political prob_word:  0.0006795379142183315 c_i:  1 prob:  0.0
# word:  discussed prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  hear prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  rights prob_word:  0.0010792660990526443 c_i:  1 prob:  0.0
# word:  maintained prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  authority prob_word:  0.0007195107327017628 c_i:  2 prob:  0.0
# word:  parliament prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  transcendent prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  uncontrollable prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  with prob_word:  0.0069552704161170405 c_i:  11 prob:  0.0
# word:  regard prob_word:  0.0002398369109005876 c_i:  2 prob:  0.0
# word:  ordinary prob_word:  1e-06 c_i:  3 prob:  0.0
# word:  objects prob_word:  0.00019986409241715632 c_i:  5 prob:  0.0
# word:  legislative prob_word:  0.00019986409241715632 c_i:  7 prob:  0.0
# word:  provision prob_word:  0.0005196466402846065 c_i:  1 prob:  0.0
# word:  accordingly prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  several prob_word:  0.0005596194587680377 c_i:  4 prob:  0.0
# word:  changed prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  acts prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  fundamental prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  articles prob_word:  0.0006795379142183315 c_i:  1 prob:  0.0
# word:  particular prob_word:  0.0008394291881520566 c_i:  3 prob:  0.0
# word:  occasions prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  last prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  occasion prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  only prob_word:  0.0013990486469200943 c_i:  4 prob:  0.0
# word:  introduced prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  septennial prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  place prob_word:  0.00039972818483431264 c_i:  3 prob:  0.0
# word:  triennial prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  same prob_word:  0.0014789942838869569 c_i:  2 prob:  0.0
# word:  act prob_word:  0.0010792660990526443 c_i:  1 prob:  0.0
# word:  continued prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  themselves prob_word:  0.0008394291881520566 c_i:  2 prob:  0.0
# word:  years prob_word:  0.00039972818483431264 c_i:  3 prob:  0.0
# word:  term prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  elected prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  an prob_word:  0.004516928488627733 c_i:  6 prob:  0.0
# word:  dangerous prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  practices prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  produced prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  very prob_word:  0.000599592277251469 c_i:  9 prob:  0.0
# word:  alarm prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  votaries prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  free prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  frequency prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  cornerstone prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  led prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  seek prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  security prob_word:  0.0004796738218011752 c_i:  4 prob:  0.0
# word:  against prob_word:  0.0008394291881520566 c_i:  2 prob:  0.0
# word:  danger prob_word:  0.00043970100331774394 c_i:  2 prob:  0.0
# word:  exposed prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  paramount prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  existed prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  could prob_word:  0.0008394291881520566 c_i:  2 prob:  0.0
# word:  obtained prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  constitutional prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  similar prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  united prob_word:  0.0009993204620857817 c_i:  3 prob:  0.0
# word:  was prob_word:  0.001798776831754407 c_i:  4 prob:  0.0
# word:  attempted prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  therefore prob_word:  0.0005596194587680377 c_i:  2 prob:  0.0
# word:  sought prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  admit prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  selecting prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  appealing prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  simple prob_word:  7.994563696686254e-05 c_i:  3 prob:  0.0
# word:  familiar prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  portion prob_word:  3.997281848343127e-05 c_i:  4 prob:  0.0
# word:  standard prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  measuring prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  innovations prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  fixing prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  national prob_word:  0.0005596194587680377 c_i:  1 prob:  0.0
# word:  sentiment prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  uniting prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  patriotic prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  exertions prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  applicable prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  year prob_word:  0.00015989127393372507 c_i:  7 prob:  0.0
# word:  hence prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  inculcated prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  laudable prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  zeal prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  erect prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  barrier prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  gradual prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  unlimited prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  advance prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  towards prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  calculated prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  distance prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  departure prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  fixed prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  necessity prob_word:  0.000599592277251469 c_i:  1 prob:  0.0
# word:  there prob_word:  0.002558260382939601 c_i:  2 prob:  0.0
# word:  applying prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  limited prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  who prob_word:  0.0013990486469200943 c_i:  4 prob:  0.0
# word:  pretend prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  liberties prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  secure prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  under prob_word:  0.0010792660990526443 c_i:  1 prob:  0.0
# word:  unalterably prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  such prob_word:  0.0016788583763041132 c_i:  4 prob:  0.0
# word:  those prob_word:  0.0020386137426549947 c_i:  5 prob:  0.0
# word:  nation prob_word:  0.0006395650957349003 c_i:  1 prob:  0.0
# word:  frequent prob_word:  0.00019986409241715632 c_i:  3 prob:  0.0
# word:  alterations prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  second prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  question prob_word:  0.00027980972938401884 c_i:  4 prob:  0.0
# word:  stated prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  whether prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  necessary prob_word:  0.0008794020066354879 c_i:  3 prob:  0.0
# word:  useful prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  propriety prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  answering prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  affirmative prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  appear prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  obvious prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  considerations prob_word:  0.0001199184554502938 c_i:  3 prob:  0.0
# word:  competent prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  legislator prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  add prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  upright prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  intention prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  sound prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  judgment prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  certain prob_word:  0.0005196466402846065 c_i:  1 prob:  0.0
# word:  degree prob_word:  0.0003597553663508814 c_i:  2 prob:  0.0
# word:  knowledge prob_word:  0.00015989127393372507 c_i:  13 prob:  0.0
# word:  subjects prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  he prob_word:  0.0019186952872047008 c_i:  3 prob:  0.0
# word:  legislate prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  part prob_word:  0.0018787224687212695 c_i:  3 prob:  0.0
# word:  acquired prob_word:  3.997281848343127e-05 c_i:  3 prob:  0.0
# word:  information prob_word:  7.994563696686254e-05 c_i:  6 prob:  0.0
# word:  lie prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  compass prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  men prob_word:  0.0013191030099532319 c_i:  2 prob:  0.0
# word:  private prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  public prob_word:  0.0013990486469200943 c_i:  6 prob:  0.0
# word:  stations prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  another prob_word:  0.0006795379142183315 c_i:  1 prob:  0.0
# word:  attained prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  at prob_word:  0.0037174721189591076 c_i:  2 prob:  0.0
# word:  least prob_word:  0.0005596194587680377 c_i:  1 prob:  0.0
# word:  thoroughly prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  actual prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  experience prob_word:  0.000599592277251469 c_i:  2 prob:  0.0
# word:  station prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  requires prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  use prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  service prob_word:  7.994563696686254e-05 c_i:  6 prob:  0.0
# word:  ought prob_word:  0.0008394291881520566 c_i:  6 prob:  0.0
# word:  proportion prob_word:  0.00043970100331774394 c_i:  3 prob:  0.0
# word:  extent prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  practical prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  requisite prob_word:  7.994563696686254e-05 c_i:  4 prob:  0.0
# word:  due prob_word:  0.00015989127393372507 c_i:  2 prob:  0.0
# word:  performance prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  branch prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  seen prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  then prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  put prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  into prob_word:  0.001199184554502938 c_i:  2 prob:  0.0
# word:  two prob_word:  0.0003597553663508814 c_i:  2 prob:  0.0
# word:  statement prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  suggests prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  answer prob_word:  0.00027980972938401884 c_i:  2 prob:  0.0
# word:  given prob_word:  0.00039972818483431264 c_i:  2 prob:  0.0
# word:  relates prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  existing prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  laws prob_word:  0.0009593476436023504 c_i:  7 prob:  0.0
# word:  uniform prob_word:  7.994563696686254e-05 c_i:  4 prob:  0.0
# word:  throughout prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  citizens prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  conversant prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  general prob_word:  0.0013990486469200943 c_i:  2 prob:  0.0
# word:  affairs prob_word:  0.00027980972938401884 c_i:  9 prob:  0.0
# word:  small prob_word:  0.00043970100331774394 c_i:  1 prob:  0.0
# word:  diversified prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  occupy prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  much prob_word:  0.0012391573729863693 c_i:  3 prob:  0.0
# word:  conversation prob_word:  1e-06 c_i:  2 prob:  0.0
# word:  every prob_word:  0.0017588040132709758 c_i:  4 prob:  0.0
# word:  class prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  theatre prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  presents prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  scene prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  far prob_word:  0.00039972818483431264 c_i:  3 prob:  0.0
# word:  being prob_word:  0.0009993204620857817 c_i:  1 prob:  0.0
# word:  vary prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  whilst prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  union prob_word:  0.0012391573729863693 c_i:  2 prob:  0.0
# word:  spread prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  extensive prob_word:  0.00031978254786745015 c_i:  2 prob:  0.0
# word:  region prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  extremely prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  t prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  e prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  local prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  connected prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  difficulty prob_word:  0.00015989127393372507 c_i:  2 prob:  0.0
# word:  correctly prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  learnt prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  central prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  councils prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  brought prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  representatives prob_word:  3.997281848343127e-05 c_i:  6 prob:  0.0
# word:  empire prob_word:  0.0002398369109005876 c_i:  1 prob:  0.0
# word:  possessed prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  members prob_word:  0.00031978254786745015 c_i:  7 prob:  0.0
# word:  each prob_word:  0.0013191030099532319 c_i:  3 prob:  0.0
# word:  how prob_word:  0.00043970100331774394 c_i:  4 prob:  0.0
# word:  foreign prob_word:  0.0008794020066354879 c_i:  3 prob:  0.0
# word:  trade prob_word:  0.0017188311947875445 c_i:  2 prob:  0.0
# word:  properly prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  regulated prob_word:  0.0001199184554502938 c_i:  2 prob:  0.0
# word:  without prob_word:  0.0012391573729863693 c_i:  3 prob:  0.0
# word:  acquaintance prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  commerce prob_word:  0.001359075828436663 c_i:  2 prob:  0.0
# word:  ports prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  usages prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  regulatious prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  duly prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  their prob_word:  0.006835351960666747 c_i:  4 prob:  0.0
# word:  relative prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  taxes prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  judiciously prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  imposed prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  effectually prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  collected prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  accommodated prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  relating prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  regulations prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  militia prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  provided prob_word:  0.0002398369109005876 c_i:  1 prob:  0.0
# word:  many prob_word:  0.0009993204620857817 c_i:  2 prob:  0.0
# word:  internal prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  principal prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  suggest prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  forcibly prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  acquire prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  interior prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  proportional prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  difficulties prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  degrees prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  diminished prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  laborious prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  task prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  proper prob_word:  0.0005596194587680377 c_i:  2 prob:  0.0
# word:  inauguration prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  primeval prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  formation prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  code prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  improvements prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  first prob_word:  0.0013191030099532319 c_i:  1 prob:  0.0
# word:  draughts prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  easier prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  fewer prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  past prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  transactions prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  ready prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  accurate prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  source prob_word:  0.0003597553663508814 c_i:  1 prob:  0.0
# word:  curiosity prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  large prob_word:  0.0005196466402846065 c_i:  2 prob:  0.0
# word:  increased prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  intercourse prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  contribute prob_word:  0.00015989127393372507 c_i:  2 prob:  0.0
# word:  diffuse prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  mutual prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  again prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  assimilation prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  manners prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  abatements prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  business prob_word:  0.0001199184554502938 c_i:  3 prob:  0.0
# word:  must prob_word:  0.002278450653555582 c_i:  2 prob:  0.0
# word:  continue prob_word:  0.00039972818483431264 c_i:  1 prob:  0.0
# word:  exceed prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  novelty prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  justify prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  longer prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  assigned prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  transact prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  belongs prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  acquirements prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  representative prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  mentioned prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  regulating prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  own prob_word:  0.0013990486469200943 c_i:  1 prob:  0.0
# word:  acquainted prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  treaties prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  nations prob_word:  0.0008794020066354879 c_i:  3 prob:  0.0
# word:  commercial prob_word:  0.0005196466402846065 c_i:  1 prob:  0.0
# word:  policy prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  altogether prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  ignorant prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  object prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  municipal prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  submitted prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  although prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  house prob_word:  1e-06 c_i:  3 prob:  0.0
# word:  immediately prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  participate prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  negotiations prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  arrangements prob_word:  3.997281848343127e-05 c_i:  2 prob:  0.0
# word:  frequently prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  deserve prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  course prob_word:  0.0006795379142183315 c_i:  3 prob:  0.0
# word:  sometimes prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  demand prob_word:  0.0002398369109005876 c_i:  1 prob:  0.0
# word:  sanction prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  cooperation prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  doubt prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  mans prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  closet prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  derived prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  sources prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  best prob_word:  0.0002398369109005876 c_i:  1 prob:  0.0
# word:  effect prob_word:  0.0002398369109005876 c_i:  2 prob:  0.0
# word:  during prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  legislature prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  importance prob_word:  0.0004796738218011752 c_i:  1 prob:  0.0
# word:  unworthy prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  notice prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  obliged prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  travel prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  rendered prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  circumstance prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  serious prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  objections prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  fit prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  extended prob_word:  0.0001199184554502938 c_i:  1 prob:  0.0
# word:  argument prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  drawn prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  delegates prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  congress prob_word:  0.0011592117360195067 c_i:  1 prob:  0.0
# word:  annually prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  reelection prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  considered prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  assemblies prob_word:  7.994563696686254e-05 c_i:  2 prob:  0.0
# word:  almost prob_word:  0.00031978254786745015 c_i:  1 prob:  0.0
# word:  matter prob_word:  0.00019986409241715632 c_i:  2 prob:  0.0
# word:  principle prob_word:  0.00027980972938401884 c_i:  1 prob:  0.0
# word:  few prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  happens prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  possess prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  superior prob_word:  0.00019986409241715632 c_i:  1 prob:  0.0
# word:  talents prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  reelections prob_word:  1e-06 c_i:  1 prob:  0.0
# word:  long prob_word:  0.00043970100331774394 c_i:  1 prob:  0.0
# word:  standing prob_word:  0.00015989127393372507 c_i:  1 prob:  0.0
# word:  masters prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  unwilling prob_word:  7.994563696686254e-05 c_i:  1 prob:  0.0
# word:  avail prob_word:  3.997281848343127e-05 c_i:  1 prob:  0.0
# word:  advantages prob_word:  0.0006395650957349003 c_i:  2 prob:  0.0
# word:  bulk prob_word:  1e-06 c_i:  1 prob:  0.0
# word:
ob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  any prob_word:  0.0018151727083444557 c_i:  6 prob:  0.0
# word:  natural prob_word:  0.00032032459559019807 c_i:  2 prob:  0.0
# word:  connection prob_word:  0.00032032459559019807 c_i:  2 prob:  0.0
# word:  subsists prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  between prob_word:  0.0011745235171640596 c_i:  7 prob:  0.0
# word:  sun prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  or prob_word:  0.00597939245101703 c_i:  12 prob:  0.0
# word:  seasons prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  period prob_word:  0.0005872617585820298 c_i:  7 prob:  0.0
# word:  within prob_word:  0.0013346858149591587 c_i:  4 prob:  0.0
# word:  human prob_word:  0.0005338743259836634 c_i:  1 prob:  0.0
# word:  virtue prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  can prob_word:  0.002028722438737921 c_i:  13 prob:  0.0
# word:  bear prob_word:  0.0002669371629918317 c_i:  3 prob:  0.0
# word:  temptations prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  power prob_word:  0.0013346858149591587 c_i:  4 prob:  0.0
# word:  happily prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  mankind prob_word:  0.0006406491911803961 c_i:  1 prob:  0.0
# word:  liberty prob_word:  0.0011745235171640596 c_i:  5 prob:  0.0
# word:  respect prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  confined prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  single prob_word:  0.0006940366237787625 c_i:  5 prob:  0.0
# word:  point prob_word:  0.0004804868933852971 c_i:  2 prob:  0.0
# word:  time prob_word:  0.0012279109497624258 c_i:  5 prob:  0.0
# word:  but prob_word:  0.0036303454166889113 c_i:  11 prob:  0.0
# word:  lies prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  extremes prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  afford prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  sufficient prob_word:  0.0003737120281885644 c_i:  2 prob:  0.0
# ...
# word:  presents prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  scene prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  far prob_word:  0.0003737120281885644 c_i:  3 prob:  0.0
# word:  being prob_word:  0.001388073247557525 c_i:  1 prob:  0.0
# word:  vary prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  whilst prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  union prob_word:  0.0021888847365330202 c_i:  2 prob:  0.0
# word:  spread prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  extensive prob_word:  0.00032032459559019807 c_i:  2 prob:  0.0
# word:  region prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  extremely prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  t prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  e prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  local prob_word:  0.0006406491911803961 c_i:  2 prob:  0.0
# word:  connected prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  difficulty prob_word:  0.00016016229779509903 c_i:  2 prob:  0.0
# word:  correctly prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  learnt prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  central prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  councils prob_word:  0.0004804868933852971 c_i:  1 prob:  0.0
# word:  brought prob_word:  0.0004804868933852971 c_i:  1 prob:  0.0
# word:  representatives prob_word:  0.0014948481127542575 c_i:  6 prob:  0.0
# word:  empire prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  possessed prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  members prob_word:  0.001548235545352624 c_i:  7 prob:  0.0
# word:  each prob_word:  0.0022422721691313864 c_i:  3 prob:  0.0
# word:  how prob_word:  0.00032032459559019807 c_i:  4 prob:  0.0
# word:  foreign prob_word:  0.0007474240563771288 c_i:  3 prob:  0.0
# word:  trade prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  properly prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  regulated prob_word:  0.00021354973039346538 c_i:  2 prob:  0.0
# word:  without prob_word:  0.0011745235171640596 c_i:  3 prob:  0.0
# word:  acquaintance prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  commerce prob_word:  0.00021354973039346538 c_i:  2 prob:  0.0
# word:  ports prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  usages prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  regulatious prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  duly prob_word:  0.00016016229779509903 c_i:  2 prob:  0.0
# word:  their prob_word:  0.006993753670385991 c_i:  4 prob:  0.0
# word:  relative prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  taxes prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  judiciously prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  imposed prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  effectually prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  collected prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  accommodated prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  relating prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  regulations prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  militia prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  provided prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  many prob_word:  0.0010677486519673268 c_i:  2 prob:  0.0
# word:  internal prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  principal prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  suggest prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  forcibly prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  acquire prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  interior prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  proportional prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  difficulties prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  degrees prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  diminished prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  laborious prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  task prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  proper prob_word:  0.0011211360845656932 c_i:  2 prob:  0.0
# word:  inauguration prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  primeval prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  formation prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  code prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  improvements prob_word:  0.0002669371629918317 c_i:  2 prob:  0.0
# word:  first prob_word:  0.0014414606801558913 c_i:  1 prob:  0.0
# word:  draughts prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  easier prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  fewer prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  past prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  transactions prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  ready prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  accurate prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  source prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  curiosity prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  large prob_word:  0.0007474240563771288 c_i:  2 prob:  0.0
# word:  increased prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  intercourse prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  contribute prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  diffuse prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  mutual prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  again prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  assimilation prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  manners prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  abatements prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  business prob_word:  0.00016016229779509903 c_i:  3 prob:  0.0
# word:  must prob_word:  0.0024024344669264855 c_i:  2 prob:  0.0
# word:  continue prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  exceed prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  novelty prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  justify prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  longer prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  assigned prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  transact prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  belongs prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  acquirements prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  representative prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  mentioned prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  regulating prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  own prob_word:  0.0009609737867705942 c_i:  1 prob:  0.0
# word:  acquainted prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  treaties prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  nations prob_word:  0.00042709946078693076 c_i:  3 prob:  0.0
# word:  commercial prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  policy prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  altogether prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  ignorant prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  object prob_word:  0.0005872617585820298 c_i:  1 prob:  0.0
# word:  municipal prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  submitted prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  although prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  house prob_word:  0.0002669371629918317 c_i:  3 prob:  0.0
# word:  immediately prob_word:  0.0004804868933852971 c_i:  1 prob:  0.0
# word:  participate prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  negotiations prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  arrangements prob_word:  0.00016016229779509903 c_i:  2 prob:  0.0
# word:  frequently prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  deserve prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  course prob_word:  0.0002669371629918317 c_i:  3 prob:  0.0
# word:  sometimes prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  demand prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  sanction prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  cooperation prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  doubt prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  mans prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  closet prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  derived prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  sources prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  best prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  effect prob_word:  0.0008541989215738615 c_i:  2 prob:  0.0
# word:  during prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  legislature prob_word:  0.0006940366237787625 c_i:  2 prob:  0.0
# word:  importance prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  unworthy prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  notice prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  obliged prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  travel prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  rendered prob_word:  0.0003737120281885644 c_i:  1 prob:  0.0
# word:  circumstance prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  serious prob_word:  0.00016016229779509903 c_i:  2 prob:  0.0
# word:  objections prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  fit prob_word:  0.0003737120281885644 c_i:  1 prob:  0.0
# word:  extended prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  argument prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  drawn prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  delegates prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  congress prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  annually prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  reelection prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  considered prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  assemblies prob_word:  0.00021354973039346538 c_i:  2 prob:  0.0
# word:  almost prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  matter prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  principle prob_word:  0.0010677486519673268 c_i:  1 prob:  0.0
# word:  few prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  happens prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  possess prob_word:  0.0003737120281885644 c_i:  1 prob:  0.0
# word:  superior prob_word:  0.0005338743259836634 c_i:  1 prob:  0.0
# word:  talents prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  reelections prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  long prob_word:  0.0006940366237787625 c_i:  1 prob:  0.0
# word:  standing prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  masters prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  unwilling prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  avail prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  advantages prob_word:  0.0004804868933852971 c_i:  2 prob:  0.0
# word:  bulk prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  apt prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  fall prob_word:  0.0003737120281885644 c_i:  1 prob:  0.0
# word:  snares prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  laid prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  remark prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  relation prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  subsist prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  senate prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  inconvenience prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  mingled prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  hold prob_word:  0.0003737120281885644 c_i:  1 prob:  0.0
# word:  session prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  spurious prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  cannot prob_word:  0.0004804868933852971 c_i:  1 prob:  0.0
# word:  investigated prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  annulled prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  decision prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  its prob_word:  0.0025092093321232183 c_i:  2 prob:  0.0
# word:  return prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  unlawful prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  irregular prob_word:  0.00016016229779509903 c_i:  2 prob:  0.0
# word:  member prob_word:  0.00032032459559019807 c_i:  2 prob:  0.0
# word:  takes prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  his prob_word:  0.0022956596017297526 c_i:  3 prob:  0.0
# word:  seat prob_word:  0.0002669371629918317 c_i:  3 prob:  0.0
# word:  sure prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  holding prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  purposes prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  pernicious prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  encouragement prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  obtaining prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  returns prob_word:  0.00010677486519673269 c_i:  2 prob:  0.0
# word:  practice prob_word:  0.0006406491911803961 c_i:  1 prob:  0.0
# word:  abuse prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  particularly prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  distant prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  necessarily prob_word:  0.00032032459559019807 c_i:  1 prob:  0.0
# word:  judge prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  qualifications prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  whatever prob_word:  0.00016016229779509903 c_i:  1 prob:  0.0
# word:  suggested prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  simplifying prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  accelerating prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  process prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  disputed prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# word:  unavoidably prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  elapse prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  illegitimate prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  dispossessed prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  prospect prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  event prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  check prob_word:  0.00021354973039346538 c_i:  1 prob:  0.0
# word:  unfair prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  illicit prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  taken prob_word:  0.00042709946078693076 c_i:  1 prob:  0.0
# word:  together prob_word:  0.0002669371629918317 c_i:  1 prob:  0.0
# word:  warrant prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  affirming prob_word:  5.3387432598366345e-05 c_i:  1 prob:  0.0
# word:  safe prob_word:  0.00010677486519673269 c_i:  1 prob:  0.0
# Hamilton Term	 0.0
# Madison Term	 0.0

# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('hamilton.txt')
    madison_word_prob = make_word_prob_map('madison.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('unknown.txt')

    print("hamilton['congress']\t", hamilton_word_prob['congress'])
    print("madison['congress']\t",  madison_word_prob['congress'])
    print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    hamilton_term = calc_log_pr_doc_given_author(hamilton_word_prob, unknown_doc_count)
    madison_term = calc_log_pr_doc_given_author(madison_word_prob, unknown_doc_count)
    print("log P(D|H)\t", hamilton_term)
    print("log P(D|M)\t",madison_term)

    print('diff\t', hamilton_term - madison_term)

def calc_log_pr_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    log_prob = math.log(1)
    for word_i, c_i in counts.items():
        p_i = get_word_prob(prob_map, word_i)
        log_prob += c_i * math.log(p_i)
    return log_prob


def calcLogProbDoc(wordProbMap, countMap):
    logProb = math.log(1)
    for wordi in countMap:
        ci = countMap[wordi]
        pi = get_word_prob(wordProbMap, wordi)
        logProb += ci * math.log(pi)
    return logProb

# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    with open(fileName , encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1

# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

if __name__ == '__main__':
    main()
# Out:
# hamilton['congress']	 0.0011592117360195067
# madison['congress']	 0.00016016229779509903
# doc_count['congress']	 1
# n_words 2172
# log P(D|H)	 -14251.749082287015
# log P(D|M)	 -12898.137397440358
# diff	 -1353.6116848466572
