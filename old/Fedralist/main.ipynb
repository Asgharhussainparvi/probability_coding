# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f = open('unknown.txt','r')
f
# Out:
# <_io.TextIOWrapper name='unknown.txt' mode='r' encoding='cp1252'>

# %%
df = pd.read_txt('unknown.txt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_txt('unknown.txt')
#
# AttributeError: module 'pandas' has no attribute 'read_txt'

# %% [markdown]
# first a open the file and store in function f

# %%
nWords = 0
wordMap = {}
for line in f:
        words = line.split(' ')
for word in words:
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1
    nWords+= 1

# %%
wordMap
# Out:
# {'No': 2,
#  'man': 1,
#  'can': 10,
#  'be': 36,
#  'a': 30,
#  'competent': 1,
#  'legislator': 1,
#  'who': 3,
#  'does': 3,
#  'not': 11,
#  'add': 1,
#  'to': 46,
#  'an': 4,
#  'upright': 1,
#  'intention': 1,
#  'and': 37,
#  'sound': 1,
#  'judgment': 1,
#  'certain': 1,
#  'degree': 2,
#  'of': 84,
#  'knowledge': 13,
#  'the': 106,
#  'subjects': 1,
#  'on': 3,
#  'which': 14,
#  'he': 2,
#  'is': 12,
#  'legislate.': 1,
#  'A': 3,
#  'part': 3,
#  'this': 8,
#  'may': 4,
#  'acquired': 3,
#  'by': 16,
#  'means': 2,
#  'information': 5,
#  'lie': 2,
#  'within': 2,
#  'compass': 1,
#  'men': 2,
#  'in': 22,
#  'private': 1,
#  'as': 12,
#  'well': 1,
#  'public': 6,
#  'stations.': 1,
#  'Another': 1,
#  'only': 3,
#  'attained,': 2,
#  'or': 2,
#  'at': 2,
#  'least': 1,
#  'thoroughly': 2,
#  'actual': 2,
#  'experience': 1,
#  'station': 1,
#  'requires': 1,
#  'use': 2,
#  'it.': 3,
#  'The': 12,
#  'period': 5,
#  'service,': 2,
#  'ought,': 1,
#  'therefore,': 1,
# ...
